# %% [markdown]
# I like to think of myself as the anti data scientist, or the troll of data science. I do my posts for me (and to entertain my one loyal reader, Sam). If I find some data to play around with and want to make a funky chart, then I can't be stopped. That's why I decided to make a word cloud of words from a Bank of Canada press release. I also decided to use R. On top of that, I am using R inside Jupyter. A slew of faux-pas.
#
# People in the data world tend to hate word clouds. Some data scientists hate them so much that they have the urge to write an entire article about why [Word Clouds are Lame](https://towardsdatascience.com/word-clouds-are-lame-263d9cbc49b7). I only skimmed this article to find a funny quote. Here is one: **_"word clouds [are] the pie chart of text data."_** So if people don't like it, of course I'm going to create it.
#
# Also, I agree that pie charts kind of suck, but I have worked in places where pie charts are the only natural, easily-digestible choice. Maybe I will create 100 pie charts for my next post.

# %% [markdown]
# # Packages
#
# I'm using `pdftools` to grab the text from the PDF press release, `tokenizers` to break up the text into sentences and words, `corpus` to analyze the words and `wordcloud` to create the word cloud. I threw `tidyverse` in there because you basically need it for everything in R.
#
# I think technically you should only have to use one of `tokenizers` or `corpus` but I found that using both gave me cleaner data.

# %%
library(pdftools)
library(tidyverse)
library(tokenizers)
library(wordcloud)
library(corpus)

# %% [markdown]
# # Download PDF, extract text and tokenize

# %%
url = "https://www.bankofcanada.ca/wp-content/uploads/2019/10/fad-press-release-2019-10-30.pdf"
file_name = "fad-press-release-2019-10-30.pdf"
download.file(url, file_name, mode = "wb")

# %% [markdown]
# I apply the `tokenize_sentences` and `tokenize_words` functions from the `tokenizers` library to the raw text to break it into sentences and words. I've picked out sentences 3 to 26 since those are the body of the text. Sentences 1 and 2 contain the letter head information and the title, so they're not useful here. Sentences after 26 are also not useful. They give information on the next press release date and the Bank's contact info.

# %%
sentences <- pdf_text(file_name) %>% tokenize_sentences()

txt <- sentences[[1]][3:26]
txt <- txt %>% tokenize_words()

# %% [markdown]
# Below is the result of tokenizing the full text and then the sentences into single words. Notice that the case has been changed to lower. There are still some things in there like numbers that we want to get rid of. For that I use the `corpus` package.

# %%
txt
# Out:
# [[1]]
#  [1] "the"      "outlook"  "for"      "the"      "global"   "economy"
#  [7] "has"      "weakened" "further"  "since"    "the"      "bank’s"
# [13] "july"     "monetary" "policy"   "report"   "mpr"
#
# [[2]]
#  [1] "ongoing"     "trade"       "conflicts"   "and"         "uncertainty"
#  [6] "are"         "restraining" "business"    "investment"  "trade"
# [11] "and"         "global"      "growth"
#
# [[3]]
#  [1] "a"         "growing"   "number"    "of"        "countries" "have"
#  [7] "responded" "with"      "monetary"  "and"       "other"     "policy"
# [13] "measures"  "to"        "support"   "their"     "economies"
#
# [[4]]
#  [1] "still"    "global"   "growth"   "is"       "expected" "to"
#  [7] "slow"     "to"       "around"   "3"        "percent"  "this"
# [13] "year"     "before"   "edging"   "up"       "over"     "the"
# [19] "next"     "two"      "years"
#
# [[5]]
# [1] "canada"       "has"          "not"          "been"         "immune"
# [6] "to"           "these"        "developments"
#
# [[6]]
# [1] "commodity" "prices"    "have"      "fallen"    "amid"      "concerns"
# [7] "about"     "global"    "demand"
#
# [[7]]
#  [1] "despite"      "this"         "the"          "canada"       "us"
#  [6] "exchange"     "rate"         "is"           "still"        "near"
# [11] "its"          "july"         "level"        "and"          "the"
# [16] "canadian"     "dollar"       "has"          "strengthened" "against"
# [21] "other"        "currencies"
#
# [[8]]
#  [1] "growth"    "in"        "canada"    "is"        "expected"  "to"
#  [7] "slow"      "in"        "the"       "second"    "half"      "of"
# [13] "this"      "year"      "to"        "a"         "rate"      "below"
# [19] "its"       "potential"
#
# [[9]]
#  [1] "this"        "reflects"    "the"         "uncertainty" "associated"
#  [6] "with"        "trade"       "conflicts"   "continuing"  "adjustment"
# [11] "in"          "the"         "energy"      "sector"      "and"
# [16] "the"         "unwinding"   "of"          "temporary"   "factors"
# [21] "that"        "boosted"     "growth"      "in"          "the"
# [26] "second"      "quarter"
#
# [[10]]
#  [1] "business"   "investment" "and"        "exports"    "are"
#  [6] "likely"     "to"         "contract"   "before"     "expanding"
# [11] "again"      "in"         "2020"       "and"        "2021"
#
# [[11]]
#  [1] "at"         "the"        "same"       "time"       "government"
#  [6] "spending"   "and"        "lower"      "borrowing"  "rates"
# [11] "are"        "supporting" "domestic"   "demand"     "and"
# [16] "activity"   "in"         "the"        "services"   "sector"
# [21] "remains"    "robust"
#
# [[12]]
#  [1] "employment" "is"         "showing"    "continuing" "strength"
#  [6] "and"        "wage"       "growth"     "is"         "picking"
# [11] "up"         "although"   "with"       "some"       "variation"
# [16] "among"      "regions"
#
# [[13]]
#  [1] "consumer"  "spending"  "has"       "been"      "choppy"    "but"
#  [7] "will"      "be"        "supported" "by"        "solid"     "income"
# [13] "growth"
#
# [[14]]
# [1] "meanwhile" "housing"   "activity"  "is"        "picking"   "up"
# [7] "in"        "most"      "markets"
#
# [[15]]
#  [1] "the"             "bank"            "continues"       "to"
#  [5] "monitor"         "the"             "evolution"       "of"
#  [9] "financial"       "vulnerabilities" "in"              "light"
# [13] "of"              "lower"           "mortgage"        "rates"
# [17] "and"             "past"            "changes"         "to"
# [21] "housing"         "market"          "policies"
#
# [[16]]
#  [1] "the"      "bank"     "projects" "real"     "gdp"      "will"
#  [7] "grow"     "by"       "1.5"      "percent"  "this"     "year"
# [13] "1.7"      "percent"  "in"       "2020"     "and"      "1.8"
# [19] "percent"  "in"       "2021"
#
# [[17]]
#  [1] "this"       "implies"    "that"       "the"        "current"
#  [6] "modest"     "output"     "gap"        "will"       "narrow"
# [11] "over"       "the"        "projection" "horizon"
#
# [[18]]
# [1] "measures"  "of"        "inflation" "are"       "all"       "around"
# [7] "2"         "percent"
#
# [[19]]
#  [1] "cpi"         "inflation"   "likely"      "will"        "dip"
#  [6] "temporarily" "in"          "2020"        "as"          "the"
# [11] "effect"      "of"          "a"           "previous"    "spike"
# [16] "in"          "energy"      "prices"      "fades"
#
# [[20]]
#  [1] "overall"    "the"        "bank"       "expects"    "inflation"
#  [6] "to"         "track"      "close"      "to"         "the"
# [11] "2"          "percent"    "target"     "over"       "the"
# [16] "projection" "horizon"
#
# [[21]]
#  [1] "all"         "things"      "considered"  "governing"   "council"
#  [6] "judges"      "it"          "appropriate" "to"          "maintain"
# [11] "the"         "current"     "level"       "of"          "the"
# [16] "overnight"   "rate"        "target"
#
# [[22]]
#  [1] "governing"    "council"      "is"           "mindful"      "that"
#  [6] "the"          "resilience"   "of"           "canada’s"     "economy"
# [11] "will"         "be"           "increasingly" "tested"       "as"
# [16] "trade"        "conflicts"    "and"          "uncertainty"  "persist"
#
# [[23]]
#  [1] "in"            "considering"   "the"           "appropriate"
#  [5] "path"          "for"           "monetary"      "policy"
#  [9] "the"           "bank"          "will"          "be"
# [13] "monitoring"    "the"           "extent"        "to"
# [17] "which"         "the"           "global"        "slowdown"
# [21] "spreads"       "beyond"        "manufacturing" "and"
# [25] "investment"
#
# [[24]]
#  [1] "in"           "this"         "context"      "it"           "will"
#  [6] "pay"          "close"        "attention"    "to"           "the"
# [11] "sources"      "of"           "resilience"   "in"           "the"
# [16] "canadian"     "economy"      "notably"      "consumer"     "spending"
# [21] "and"          "housing"      "activity"     "as"           "well"
# [26] "as"           "to"           "fiscal"       "policy"       "developments"

# %% [markdown]
# # Convert to corpus data frame
#
# The `corpus` package makes working with text data easier. I've decided to apply corpus functions to my already-tokenized text as I found that just using the `tokenizers` library wasn't enough. Corpus allows you to create corpus data frame objects using `corpus_frame`. The corpus library still lets you pass other object types as inputs, such as a regular `data.frame`. However, passing a corpus data frame gives you more functionality, such as the ability to apply the `text_filter` function, which filters out things like punctuation and numbers. See [this vignette](https://cran.r-project.org/web/packages/corpus/vignettes/corpus.html) for an introduction to corpus.
#
# **Important note: the `corpus_frame` function expects the input to have a column called `text`.**

# %%
names(txt) <- paste("page", seq_along(txt), sep = "")

# convert to normal data frame
df = data.frame(text)

for (item in txt)
{
    df_temp = data.frame(text = item)
    df <- rbind(df, df_temp)
}

# convert to corpus data frame
data <- corpus_frame(df)

# %% [markdown]
# # Filter out numbers and punctuation
#
# The default options for `drop_number` and `drop_punc` are set to `FALSE`, so we need to change those in the `text_filter` properties:

# %%
text_filter(data)$drop_number <- TRUE
text_filter(data)$drop_punct <- TRUE

# %% [markdown]
# # Create a list of Bank-specific stop words
#
# Stop words are common words, such as "the", that we need to instruct the program to ignore. Bank of Canada press releases tend to use a handful of words common to economics so I've decided to create a custom stop word list to filter them out.

# %%
boc_stopwords <- c('per','cent', 'percent','rate','rates','bank',"bank\'s",'canada',
                   'monetary','policy','report','mpr','governing','council','year',
                   'january','february','march','april','may','june','july','august',
                   'september','october','november','december')

# %% [markdown]
# # Tally word counts
#
# Corpus has a term_stats function that counts all the instances of words. Below we see that "growth" is the most frequently used term. Coming from a central bank, that's not suprising.

# %%
term_stats <- term_stats(data, subset = !term %in% boc_stopwords & !term %in% stopwords_en)
head(term_stats)
# Out:
#   term      count support
# 1 growth    6     6
# 2 global    5     5
# 3 trade     4     4
# 4 activity  3     3
# 5 conflicts 3     3
# 6 economy   3     3

# %% [markdown]
# # Create word cloud

# %%
# save image
png("oct2019.png", width=12,height=8, units='in', res=300)

wordcloud(words = term_stats$term, freq = term_stats$count, min.freq = 1,
          max.words=500, random.order=FALSE, rot.per=0.35, 
          colors=brewer.pal(6, "Dark2"))

# %% [markdown]
# ![](oct2019.png)
